# %%
import pandas as pd
from datetime import datetime
import sqlite3

# %%
# https://fftoday.com/nfl/schedule.php

# %%
df = pd.read_csv("schedule.csv", skiprows=1)

# %%
df['Date'] = df['Date'].fillna(method='ffill')
# Out:
# /tmp/ipykernel_538544/1291857192.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Date'] = df['Date'].fillna(method='ffill')

# %%
df
# Out:
#                                                   Date Time (ET)  \
# 0                                            Thu Sep 5   8:20 pm
# 1                                            Fri Sep 6   8:15 pm
# 2                                            Sun Sep 8   1:00 pm
# 3                                            Sun Sep 8   1:00 pm
# 4                                            Sun Sep 8   1:00 pm
# ..                                                 ...       ...
# 312                                          Sun Jan 5   1:00 pm
# 313                                          Sun Jan 5   1:00 pm
# 314                                          Sun Jan 5   1:00 pm
# 315                                          Sun Jan 5   1:00 pm
# 316  * Tentative flex schedule game, start time is ...       NaN
#
#                  Away Team              Home Team
# 0         Baltimore Ravens     Kansas City Chiefs
# 1        Green Bay Packers  Philadelphia Eagles ¹
# 2        Arizona Cardinals          Buffalo Bills
# 3        Carolina Panthers     New Orleans Saints
# 4           Houston Texans     Indianapolis Colts
# ..                     ...                    ...
# 312        New York Giants  Philadelphia Eagles *
# 313    San Francisco 49ers    Arizona Cardinals *
# 314       Seattle Seahawks     Los Angeles Rams *
# 315  Washington Commanders       Dallas Cowboys *
# 316                    NaN                    NaN
#
# [317 rows x 4 columns]

# %%
def parse_date(date_str):
    date = pd.to_datetime(date_str, format='%a %b %d', errors='coerce')
    current_year = datetime.now().year
    
    # If the month is January, set the year to next year
    if date.month == 1:
        return date.replace(year=current_year + 1)
    else:
        return date.replace(year=current_year)

df['Date'] = df['Date'].apply(parse_date)

# %%
df.dropna(subset=['Date'], inplace=True)

# %%
import re
# Remove ' ¹' or '*' from the end of the Home Team column
df['Home Team'] = df['Home Team'].str.replace(r'[ ¹*]+$', '', regex=True)

# %%
df['DateTime'] = pd.to_datetime(df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Time (ET)'])
# Out:
# /tmp/ipykernel_538544/364424183.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime'] = pd.to_datetime(df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Time (ET)'])

# %%
df = df[['DateTime', 'Away Team', 'Home Team']].rename(columns={'DateTime': 'datetime', 'Away Team': 'away_team', 'Home Team': 'home_team'})

# %%
df = df.reset_index(names='game_id')

# %%
df
# Out:
#      game_id            datetime              away_team             home_team
# 0          0 2024-09-05 20:20:00       Baltimore Ravens    Kansas City Chiefs
# 1          1 2024-09-06 20:15:00      Green Bay Packers   Philadelphia Eagles
# 2          2 2024-09-08 13:00:00      Arizona Cardinals         Buffalo Bills
# 3          3 2024-09-08 13:00:00      Carolina Panthers    New Orleans Saints
# 4          4 2024-09-08 13:00:00         Houston Texans    Indianapolis Colts
# ..       ...                 ...                    ...                   ...
# 267      311 2025-01-05 13:00:00     New Orleans Saints  Tampa Bay Buccaneers
# 268      312 2025-01-05 13:00:00        New York Giants   Philadelphia Eagles
# 269      313 2025-01-05 13:00:00    San Francisco 49ers     Arizona Cardinals
# 270      314 2025-01-05 13:00:00       Seattle Seahawks      Los Angeles Rams
# 271      315 2025-01-05 13:00:00  Washington Commanders        Dallas Cowboys
#
# [272 rows x 4 columns]

# %%
df.to_parquet("schedule.parquet")

# %%
conn = sqlite3.connect('data/main.db')
df.to_sql('schedule', conn, if_exists='replace', index=True, index_label='game_id')
conn.close()

# %%
df
# Out:
#                datetime              away_team             home_team
# 0   2024-09-05 20:20:00       Baltimore Ravens    Kansas City Chiefs
# 1   2024-09-06 20:15:00      Green Bay Packers   Philadelphia Eagles
# 2   2024-09-08 13:00:00      Arizona Cardinals         Buffalo Bills
# 3   2024-09-08 13:00:00      Carolina Panthers    New Orleans Saints
# 4   2024-09-08 13:00:00         Houston Texans    Indianapolis Colts
# ..                  ...                    ...                   ...
# 311 2025-01-05 13:00:00     New Orleans Saints  Tampa Bay Buccaneers
# 312 2025-01-05 13:00:00        New York Giants   Philadelphia Eagles
# 313 2025-01-05 13:00:00    San Francisco 49ers     Arizona Cardinals
# 314 2025-01-05 13:00:00       Seattle Seahawks      Los Angeles Rams
# 315 2025-01-05 13:00:00  Washington Commanders        Dallas Cowboys
#
# [272 rows x 3 columns]

# %%
import requests
import os

api_key = os.environ.get('ODDS_API_KEY')
r = requests.get(f"https://api.the-odds-api.com/v4/sports/americanfootball_nfl/scores/?daysFrom=3&apiKey={api_key}")
results = pd.DataFrame(r.json())

# %%
# Explode the 'scores' column to create separate rows for each team's score
results_exploded = results.explode('scores')

# Extract 'name' and 'score' from the 'scores' dictionary
results_exploded['team'] = results_exploded['scores'].apply(lambda x: x['name'] if x else None)
results_exploded['score'] = results_exploded['scores'].apply(lambda x: x['score'] if x else None)

# Drop the original 'scores' column
results_exploded = results_exploded.drop('scores', axis=1)

# Pivot the table to have home and away scores in separate columns
results_fixed = results_exploded.pivot(index=['id', 'sport_key', 'sport_title', 'commence_time', 'completed', 'home_team', 'away_team', 'last_update'],
                                       columns='team',
                                       values='score').reset_index()

# Rename columns to distinguish between home and away scores
results_fixed.columns.name = None
results_fixed = results_fixed.rename(columns={
    results_fixed.columns[-2]: 'away_score',
    results_fixed.columns[-1]: 'home_score'
})

# %%
results_fixed
# Out:
#                                   id             sport_key sport_title  \
# 0   111ac41e21c6f16a2d3d1511f07e2004  americanfootball_nfl         NFL
# 1   17d4d840f9f4094d76c6e9b53b18ac05  americanfootball_nfl         NFL
# 2   200c20527d1d6f44257155548cdac1e8  americanfootball_nfl         NFL
# 3   2cefb0f9bcf18ed3f64396174ece14ad  americanfootball_nfl         NFL
# 4   2ee776f967540a404694111f27822004  americanfootball_nfl         NFL
# 5   326301fd41fe90d64929b44a2e227b23  americanfootball_nfl         NFL
# 14  2024-09-22T17:01:00Z      False       Tennessee Titans
# 15  2024-09-22T17:00:00Z      False   Tampa Bay Buccaneers
# 16  2024-09-24T00:15:00Z      False     Cincinnati Bengals
# 17  2024-09-23T23:31:00Z      False          Buffalo Bills
# 18  2024-09-15T17:00:00Z      False      Minnesota Vikings
# 19  2024-09-15T17:00:00Z      False      Carolina Panthers
# 20  2024-09-23T00:20:00Z      False        Atlanta Falcons
# 21  2024-09-15T17:00:00Z      False      Green Bay Packers
# 22  2024-09-22T20:25:00Z      False         Dallas Cowboys
# 23  2024-09-15T20:05:00Z      False      Arizona Cardinals
# 24  2024-09-13T00:16:05Z       True         Miami Dolphins
# 25  2024-09-22T17:00:00Z      False     Indianapolis Colts
# 26  2024-09-22T20:25:00Z      False      Arizona Cardinals
# 27  2024-09-22T20:25:00Z      False       Los Angeles Rams
# 28  2024-09-15T20:25:00Z      False     Kansas City Chiefs
# 29  2024-09-22T17:00:00Z      False      Minnesota Vikings
# 30  2024-09-20T00:15:00Z      False          New York Jets
#
#                 away_team           last_update   NaN away_score home_score
# 0        Cleveland Browns                   NaN  None        NaN        NaN
# 1           New York Jets                   NaN  None        NaN        NaN
# 2         New York Giants                   NaN  None        NaN        NaN
# 3         Atlanta Falcons                   NaN  None        NaN        NaN
# 4    Los Angeles Chargers                   NaN  None        NaN        NaN
# 5     Philadelphia Eagles                   NaN  None        NaN        NaN
# 6     Pittsburgh Steelers                   NaN  None        NaN        NaN
# 7        Seattle Seahawks                   NaN  None        NaN        NaN
# 8       Carolina Panthers                   NaN  None        NaN        NaN
# 9         New York Giants                   NaN  None        NaN        NaN
# 10      Las Vegas Raiders                   NaN  None        NaN        NaN
# 11     New Orleans Saints                   NaN  None        NaN        NaN
# 12          Chicago Bears                   NaN  None        NaN        NaN
# 13   Tampa Bay Buccaneers                   NaN  None        NaN        NaN
# 14      Green Bay Packers                   NaN  None        NaN        NaN
# 15         Denver Broncos                   NaN  None        NaN        NaN
# 16  Washington Commanders                   NaN  None        NaN        NaN
# 17   Jacksonville Jaguars                   NaN  None        NaN        NaN
# 18    San Francisco 49ers                   NaN  None        NaN        NaN
# 19   Los Angeles Chargers                   NaN  None        NaN        NaN
# 20     Kansas City Chiefs                   NaN  None        NaN        NaN
# 21     Indianapolis Colts                   NaN  None        NaN        NaN
# 22       Baltimore Ravens                   NaN  None        NaN        NaN
# 23       Los Angeles Rams                   NaN  None        NaN        NaN
# 24          Buffalo Bills  2024-09-13T08:39:25Z   NaN         31         10
# 25          Chicago Bears                   NaN  None        NaN        NaN
# 26          Detroit Lions                   NaN  None        NaN        NaN
# 27    San Francisco 49ers                   NaN  None        NaN        NaN
# 28     Cincinnati Bengals                   NaN  None        NaN        NaN
# 29         Houston Texans                   NaN  None        NaN        NaN
# 30   New England Patriots                   NaN  None        NaN        NaN
