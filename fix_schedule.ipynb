# %%
import pandas as pd
from datetime import datetime
import sqlite3

# %%
# https://fftoday.com/nfl/schedule.php

# %%
df = pd.read_csv("schedule.csv", skiprows=1)

# %%
df['Date'] = df['Date'].fillna(method='ffill')
# Out:
# /tmp/ipykernel_538544/1291857192.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Date'] = df['Date'].fillna(method='ffill')

# %%
df
# Out:
#                                                   Date Time (ET)  \
# 0                                            Thu Sep 5   8:20 pm
# 1                                            Fri Sep 6   8:15 pm
# 2                                            Sun Sep 8   1:00 pm
# 3                                            Sun Sep 8   1:00 pm
# 4                                            Sun Sep 8   1:00 pm
# ..                                                 ...       ...
# 312                                          Sun Jan 5   1:00 pm
# 313                                          Sun Jan 5   1:00 pm
# 314                                          Sun Jan 5   1:00 pm
# 315                                          Sun Jan 5   1:00 pm
# 316  * Tentative flex schedule game, start time is ...       NaN
#
#                  Away Team              Home Team
# 0         Baltimore Ravens     Kansas City Chiefs
# 1        Green Bay Packers  Philadelphia Eagles ¹
# 2        Arizona Cardinals          Buffalo Bills
# 3        Carolina Panthers     New Orleans Saints
# 4           Houston Texans     Indianapolis Colts
# ..                     ...                    ...
# 312        New York Giants  Philadelphia Eagles *
# 313    San Francisco 49ers    Arizona Cardinals *
# 314       Seattle Seahawks     Los Angeles Rams *
# 315  Washington Commanders       Dallas Cowboys *
# 316                    NaN                    NaN
#
# [317 rows x 4 columns]

# %%
def parse_date(date_str):
    date = pd.to_datetime(date_str, format='%a %b %d', errors='coerce')
    current_year = datetime.now().year
    
    # If the month is January, set the year to next year
    if date.month == 1:
        return date.replace(year=current_year + 1)
    else:
        return date.replace(year=current_year)

df['Date'] = df['Date'].apply(parse_date)

# %%
df.dropna(subset=['Date'], inplace=True)

# %%
import re
# Remove ' ¹' or '*' from the end of the Home Team column
df['Home Team'] = df['Home Team'].str.replace(r'[ ¹*]+$', '', regex=True)

# %%
df['DateTime'] = pd.to_datetime(df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Time (ET)'])
# Out:
# /tmp/ipykernel_538544/364424183.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime'] = pd.to_datetime(df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Time (ET)'])

# %%
df = df[['DateTime', 'Away Team', 'Home Team']].rename(columns={'DateTime': 'datetime', 'Away Team': 'away_team', 'Home Team': 'home_team'})

# %%
df = df.reset_index(names='game_id')

# %%
df
# Out:
#      game_id            datetime              away_team             home_team
# 0          0 2024-09-05 20:20:00       Baltimore Ravens    Kansas City Chiefs
# 1          1 2024-09-06 20:15:00      Green Bay Packers   Philadelphia Eagles
# 2          2 2024-09-08 13:00:00      Arizona Cardinals         Buffalo Bills
# 3          3 2024-09-08 13:00:00      Carolina Panthers    New Orleans Saints
# 4          4 2024-09-08 13:00:00         Houston Texans    Indianapolis Colts
# ..       ...                 ...                    ...                   ...
# 267      311 2025-01-05 13:00:00     New Orleans Saints  Tampa Bay Buccaneers
# 268      312 2025-01-05 13:00:00        New York Giants   Philadelphia Eagles
# 269      313 2025-01-05 13:00:00    San Francisco 49ers     Arizona Cardinals
# 270      314 2025-01-05 13:00:00       Seattle Seahawks      Los Angeles Rams
# 271      315 2025-01-05 13:00:00  Washington Commanders        Dallas Cowboys
#
# [272 rows x 4 columns]

# %%
df.to_parquet("schedule.parquet")

# %%
conn = sqlite3.connect('data/main.db')
df.to_sql('schedule', conn, if_exists='replace', index=True, index_label='game_id')
conn.close()

# %%
df
# Out:
#                datetime              away_team             home_team
# 0   2024-09-05 20:20:00       Baltimore Ravens    Kansas City Chiefs
# 1   2024-09-06 20:15:00      Green Bay Packers   Philadelphia Eagles
# 2   2024-09-08 13:00:00      Arizona Cardinals         Buffalo Bills
# 3   2024-09-08 13:00:00      Carolina Panthers    New Orleans Saints
# 4   2024-09-08 13:00:00         Houston Texans    Indianapolis Colts
# ..                  ...                    ...                   ...
# 311 2025-01-05 13:00:00     New Orleans Saints  Tampa Bay Buccaneers
# 312 2025-01-05 13:00:00        New York Giants   Philadelphia Eagles
# 313 2025-01-05 13:00:00    San Francisco 49ers     Arizona Cardinals
# 314 2025-01-05 13:00:00       Seattle Seahawks      Los Angeles Rams
# 315 2025-01-05 13:00:00  Washington Commanders        Dallas Cowboys
#
# [272 rows x 3 columns]

# %%
import requests
import os
import pandas as pd

from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('ODDS_API_KEY')
r = requests.get(f"https://api.the-odds-api.com/v4/sports/americanfootball_nfl/scores/?daysFrom=3&apiKey={api_key}")
results = pd.DataFrame(r.json())

# %%
results
# Out:
#                                   id             sport_key sport_title  \
# 0   ddd9b67cf1d68282e1e8652000c0d015  americanfootball_nfl         NFL
# 1   5a2bfc721fb2300d4578743aee7ad891  americanfootball_nfl         NFL
# 2   111ac41e21c6f16a2d3d1511f07e2004  americanfootball_nfl         NFL
# 3   787ae4144b2b45d7ef8a9c7b1ab6abd8  americanfootball_nfl         NFL
# 4   c4e5642a8746f3e8fbb09d59a611ffe4  americanfootball_nfl         NFL
# 5   9d5dace601f10c135f5c03facf23fd22  americanfootball_nfl         NFL
# 6   42d27889b51ada96c20671b30129ce4e  americanfootball_nfl         NFL
# 7   17d4d840f9f4094d76c6e9b53b18ac05  americanfootball_nfl         NFL
# 8   5b05775b536cda3f2efab93935af4f54  americanfootball_nfl         NFL
# 9   495d9f2c316b05ef092099ef9401a180  americanfootball_nfl         NFL
# 10  b4769cda12183128858f49f475aabfce  americanfootball_nfl         NFL
# 11  db997fc1b5fe71f4960012f81c21a017  americanfootball_nfl         NFL
# 12  faaeaab20409da65e7314cc1857ccfba  americanfootball_nfl         NFL
# 13  3a300e2fb659ca896b5e60252f13150c  americanfootball_nfl         NFL
# 14  7533f0f2d5cfe270fa0ccdc32a98c7fd  americanfootball_nfl         NFL
# 15  2cefb0f9bcf18ed3f64396174ece14ad  americanfootball_nfl         NFL
# 16  ff0f310a02a527f105b5b37dbd61c502  americanfootball_nfl         NFL
# 17  200c20527d1d6f44257155548cdac1e8  americanfootball_nfl         NFL
# 18  81cee90c26bf0ec45c3bc946b8143e19  americanfootball_nfl         NFL
# 19  e46e4c9f5d6884910657cd6581da3978  americanfootball_nfl         NFL
# 20  fc293a1ac914f24cb110ed2b8250292d  americanfootball_nfl         NFL
# 21  49397bc00cf6d5e50f0a943538f1b00d  americanfootball_nfl         NFL
# 22  cd904fbb09c5130b857595217364bb07  americanfootball_nfl         NFL
# 23  96be3ba73fc562e49a0120b5923c3213  americanfootball_nfl         NFL
#
#            commence_time  completed              home_team  \
# 0   2024-09-13T00:16:05Z       True         Miami Dolphins
# 1   2024-09-15T17:02:00Z       True       Baltimore Ravens
# 2   2024-09-15T17:02:00Z       True   Jacksonville Jaguars
# 3   2024-09-15T17:02:00Z       True          Detroit Lions
# 4   2024-09-15T17:02:00Z       True      Green Bay Packers
# 5   2024-09-15T17:02:00Z       True      Minnesota Vikings
# 6   2024-09-15T17:02:00Z       True   New England Patriots
# 7   2024-09-15T17:02:39Z       True       Tennessee Titans
# 8   2024-09-15T17:02:45Z       True         Dallas Cowboys
# 9   2024-09-15T17:02:58Z       True  Washington Commanders
# 10  2024-09-15T17:03:17Z       True      Carolina Panthers
# 11  2024-09-15T20:05:00Z      False      Arizona Cardinals
# 12  2024-09-15T20:26:17Z      False     Kansas City Chiefs
# 13  2024-09-15T20:26:41Z      False         Denver Broncos
# 14  2024-09-16T00:20:00Z      False         Houston Texans
# 15  2024-09-17T00:15:00Z      False    Philadelphia Eagles
# 16  2024-09-20T00:15:00Z      False          New York Jets
# 17  2024-09-22T17:00:00Z      False       Cleveland Browns
# 18  2024-09-22T17:00:00Z      False       Tennessee Titans
# 19  2024-09-22T17:01:00Z      False     Indianapolis Colts
# 20  2024-09-22T17:01:00Z      False      Minnesota Vikings
# 21  2024-09-22T20:05:00Z      False      Las Vegas Raiders
# 22  2024-09-22T20:25:00Z      False         Dallas Cowboys
# 23  2024-09-23T23:30:00Z      False          Buffalo Bills
#
#                away_team                                             scores  \
# 0          Buffalo Bills  [{'name': 'Buffalo Bills', 'score': '31'}, {'n...
# 1      Las Vegas Raiders  [{'name': 'Las Vegas Raiders', 'score': '26'},...
# 2       Cleveland Browns  [{'name': 'Cleveland Browns', 'score': '18'}, ...
# 3   Tampa Bay Buccaneers  [{'name': 'Tampa Bay Buccaneers', 'score': '20...
# 4     Indianapolis Colts  [{'name': 'Indianapolis Colts', 'score': '10'}...
# 5    San Francisco 49ers  [{'name': 'San Francisco 49ers', 'score': '17'...
# 6       Seattle Seahawks  [{'name': 'Seattle Seahawks', 'score': '23'}, ...
# 7          New York Jets  [{'name': 'New York Jets', 'score': '24'}, {'n...
# 8     New Orleans Saints  [{'name': 'New Orleans Saints', 'score': '44'}...
# 9        New York Giants  [{'name': 'New York Giants', 'score': '18'}, {...
# 10  Los Angeles Chargers  [{'name': 'Los Angeles Chargers', 'score': '26...
# 11      Los Angeles Rams  [{'name': 'Los Angeles Rams', 'score': '10'}, ...
# 12    Cincinnati Bengals  [{'name': 'Cincinnati Bengals', 'score': '16'}...
# 13   Pittsburgh Steelers  [{'name': 'Pittsburgh Steelers', 'score': '13'...
# 14         Chicago Bears                                               None
# 15       Atlanta Falcons                                               None
# 16  New England Patriots                                               None
# 17       New York Giants                                               None
# 18     Green Bay Packers                                               None
# 19         Chicago Bears                                               None
# 20        Houston Texans                                               None
# 21     Carolina Panthers                                               None
# 22      Baltimore Ravens                                               None
# 23  Jacksonville Jaguars                                               None
#
#              last_update
# 0   2024-09-15T22:33:22Z
# 1   2024-09-15T22:33:22Z
# 2   2024-09-15T22:33:22Z
# 3   2024-09-15T22:33:22Z
# 4   2024-09-15T22:33:22Z
# 5   2024-09-15T22:33:22Z
# 6   2024-09-15T22:33:22Z
# 7   2024-09-15T22:33:22Z
# 8   2024-09-15T22:33:22Z
# 9   2024-09-15T22:33:22Z
# 10  2024-09-15T22:33:22Z
# 11  2024-09-15T22:33:22Z
# 12  2024-09-15T22:33:22Z
# 13  2024-09-15T22:33:22Z
# 14                  None
# 15                  None
# 16                  None
# 17                  None
# 18                  None
# 19                  None
# 20                  None
# 21                  None
# 22                  None
# 23                  None

# %%
# ... existing code ...

# Explode the 'scores' column to create separate rows for each team's score
results_exploded = results.explode('scores')

# Extract 'name' and 'score' from the 'scores' dictionary
results_exploded['team'] = results_exploded['scores'].apply(lambda x: x['name'] if isinstance(x, dict) and 'name' in x else None)
results_exploded['score'] = results_exploded['scores'].apply(lambda x: x['score'] if isinstance(x, dict) and 'score' in x else None)

# Drop the original 'scores' column
results_exploded = results_exploded.drop('scores', axis=1)

# Create separate columns for home and away scores
def get_scores(group):
    home_team = group['home_team'].iloc[0] if 'home_team' in group.columns and not group.empty else None
    away_team = group['away_team'].iloc[0] if 'away_team' in group.columns and not group.empty else None
    
    home_score = group[group['team'] == home_team]['score'].iloc[0] if home_team and not group[group['team'] == home_team].empty else None
    away_score = group[group['team'] == away_team]['score'].iloc[0] if away_team and not group[group['team'] == away_team].empty else None
    
    return pd.Series({'home_team_score': home_score, 'away_team_score': away_score})

results_fixed = results_exploded.groupby('id', as_index=False).apply(get_scores)

# Merge the scores back with the original data
results_fixed = results.merge(results_fixed, on='id', how='left')

# Reorder columns for better readability
column_order = ['id', 'sport_key', 'sport_title', 'commence_time', 'completed', 'home_team', 'away_team', 'home_team_score', 'away_team_score', 'last_update']
results_fixed = results_fixed[column_order]

# ... existing code ...

# %%
results_fixed
# Out:
#                                   id             sport_key sport_title  \
# 0   ddd9b67cf1d68282e1e8652000c0d015  americanfootball_nfl         NFL
# 1   5a2bfc721fb2300d4578743aee7ad891  americanfootball_nfl         NFL
# 2   111ac41e21c6f16a2d3d1511f07e2004  americanfootball_nfl         NFL
# 3   787ae4144b2b45d7ef8a9c7b1ab6abd8  americanfootball_nfl         NFL
# 4   c4e5642a8746f3e8fbb09d59a611ffe4  americanfootball_nfl         NFL
# 5   9d5dace601f10c135f5c03facf23fd22  americanfootball_nfl         NFL
# 6   42d27889b51ada96c20671b30129ce4e  americanfootball_nfl         NFL
# 7   17d4d840f9f4094d76c6e9b53b18ac05  americanfootball_nfl         NFL
# 8   5b05775b536cda3f2efab93935af4f54  americanfootball_nfl         NFL
# 9   495d9f2c316b05ef092099ef9401a180  americanfootball_nfl         NFL
# 10  b4769cda12183128858f49f475aabfce  americanfootball_nfl         NFL
# 11  db997fc1b5fe71f4960012f81c21a017  americanfootball_nfl         NFL
# 12  faaeaab20409da65e7314cc1857ccfba  americanfootball_nfl         NFL
# 13  3a300e2fb659ca896b5e60252f13150c  americanfootball_nfl         NFL
# 14  7533f0f2d5cfe270fa0ccdc32a98c7fd  americanfootball_nfl         NFL
# 15  2cefb0f9bcf18ed3f64396174ece14ad  americanfootball_nfl         NFL
# 16  ff0f310a02a527f105b5b37dbd61c502  americanfootball_nfl         NFL
# 17  200c20527d1d6f44257155548cdac1e8  americanfootball_nfl         NFL
# 18  81cee90c26bf0ec45c3bc946b8143e19  americanfootball_nfl         NFL
# 19  e46e4c9f5d6884910657cd6581da3978  americanfootball_nfl         NFL
# 20  fc293a1ac914f24cb110ed2b8250292d  americanfootball_nfl         NFL
# 21  49397bc00cf6d5e50f0a943538f1b00d  americanfootball_nfl         NFL
# 22  cd904fbb09c5130b857595217364bb07  americanfootball_nfl         NFL
# 23  96be3ba73fc562e49a0120b5923c3213  americanfootball_nfl         NFL
#
#            commence_time  completed              home_team  \
# 0   2024-09-13T00:16:05Z       True         Miami Dolphins
# 1   2024-09-15T17:02:00Z       True       Baltimore Ravens
# 2   2024-09-15T17:02:00Z       True   Jacksonville Jaguars
# 3   2024-09-15T17:02:00Z       True          Detroit Lions
# 4   2024-09-15T17:02:00Z       True      Green Bay Packers
# 5   2024-09-15T17:02:00Z       True      Minnesota Vikings
# 6   2024-09-15T17:02:00Z       True   New England Patriots
# 7   2024-09-15T17:02:39Z       True       Tennessee Titans
# 8   2024-09-15T17:02:45Z       True         Dallas Cowboys
# 9   2024-09-15T17:02:58Z       True  Washington Commanders
# 10  2024-09-15T17:03:17Z       True      Carolina Panthers
# 11  2024-09-15T20:05:00Z      False      Arizona Cardinals
# 12  2024-09-15T20:26:17Z      False     Kansas City Chiefs
# 13  2024-09-15T20:26:41Z      False         Denver Broncos
# 14  2024-09-16T00:20:00Z      False         Houston Texans
# 15  2024-09-17T00:15:00Z      False    Philadelphia Eagles
# 16  2024-09-20T00:15:00Z      False          New York Jets
# 17  2024-09-22T17:00:00Z      False       Cleveland Browns
# 18  2024-09-22T17:00:00Z      False       Tennessee Titans
# 19  2024-09-22T17:01:00Z      False     Indianapolis Colts
# 20  2024-09-22T17:01:00Z      False      Minnesota Vikings
# 21  2024-09-22T20:05:00Z      False      Las Vegas Raiders
# 22  2024-09-22T20:25:00Z      False         Dallas Cowboys
# 23  2024-09-23T23:30:00Z      False          Buffalo Bills
#
#                away_team home_team_score away_team_score           last_update
# 0          Buffalo Bills              10              31  2024-09-15T22:33:22Z
# 1      Las Vegas Raiders              23              26  2024-09-15T22:33:22Z
# 2       Cleveland Browns              13              18  2024-09-15T22:33:22Z
# 3   Tampa Bay Buccaneers              16              20  2024-09-15T22:33:22Z
# 4     Indianapolis Colts              16              10  2024-09-15T22:33:22Z
# 5    San Francisco 49ers              23              17  2024-09-15T22:33:22Z
# 6       Seattle Seahawks              20              23  2024-09-15T22:33:22Z
# 7          New York Jets              17              24  2024-09-15T22:33:22Z
# 8     New Orleans Saints              19              44  2024-09-15T22:33:22Z
# 9        New York Giants              21              18  2024-09-15T22:33:22Z
# 10  Los Angeles Chargers               3              26  2024-09-15T22:33:22Z
# 11      Los Angeles Rams              41              10  2024-09-15T22:33:22Z
# 12    Cincinnati Bengals              17              16  2024-09-15T22:33:22Z
# 13   Pittsburgh Steelers               0              13  2024-09-15T22:33:22Z
# 14         Chicago Bears            None            None                  None
# 15       Atlanta Falcons            None            None                  None
# 16  New England Patriots            None            None                  None
# 17       New York Giants            None            None                  None
# 18     Green Bay Packers            None            None                  None
# 19         Chicago Bears            None            None                  None
# 20        Houston Texans            None            None                  None
# 21     Carolina Panthers            None            None                  None
# 22      Baltimore Ravens            None            None                  None
# 23  Jacksonville Jaguars            None            None                  None
